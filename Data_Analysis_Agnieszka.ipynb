# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data1 = pd.read_csv('Mobile_App_Store_Data/appleStore.csv')
data2 = pd.read_csv('Mobile_App_Store_Data/appleStore_description.csv')

# merge data
data = pd.merge(data1, data2, how='outer', on=['id', 'id'])

# clean
data = data.drop('Unnamed: 0', axis=1)
data = data.drop('track_name_y', axis=1)
data = data.drop('size_bytes_y', axis=1)

# show
data.head(3)
# Out:
#           id                                     track_name_x  size_bytes_x  \
# 0  281656475                                  PAC-MAN Premium     100788224
# 1  281796108                        Evernote - stay organized     158578688
# 2  281940292  WeatherBug - Local Weather, Radar, Maps, Alerts     100524032
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
#
#    user_rating_ver    ver cont_rating   prime_genre  sup_devices.num  \
# 0              4.5  6.3.5          4+         Games               38
# 1              3.5  8.2.2          4+  Productivity               37
# 2              4.5  5.0.0          4+       Weather               37
#
#    ipadSc_urls.num  lang.num  vpp_lic  \
# 0                5        10        1
# 1                5        23        1
# 2                5         3        1
#
#                                             app_desc
# 0  SAVE 20%, now only $3.99 for a limited time!\n...
# 1  Let Evernote change the way you organize your ...
# 2  Download the most popular free weather app pow...

# %% [markdown]
# # QUESTION 1
# Distribution of app prices (count of apps according to price plotted as histogram)

# %%
hist_plot = data['price'].hist(bins=15, figsize=(12,4), log=True)
hist_plot.set_title('Number of apps per price in AppStore')
hist_plot.set_xlabel('price')
hist_plot.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# conclusion: most of the apps available in AppStore is for free or for small amount of money.

# %% [markdown]
# # QUESTION 2
# Depends Average User Rating Value on any other variable e.g. number of User Rating counts (all version)?

# %%
def rating_count_group(rating):
    if rating < 10000:
        return 'below 10k'
    elif 10000 <= rating < 50000:
        return 'between 10k and 50k'
    elif 50000 <= rating <= 100000:
        return 'between 50k and 100k'
    else: 
        return'more than 100k'

data['rating_group'] = data.apply(lambda x: rating_count_group(x['rating_count_tot']),axis=1)
data
# Out:
#               id                                       track_name_x  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# ...          ...                                                ...
# 7192  1187617475                                              Kubik
# 7193  1187682390                                  VR Roller-Coaster
# 7194  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 7195  1187838770          VR Roller Coaster World - Virtual Reality
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes_x currency  price  rating_count_tot  rating_count_ver  \
# 0        100788224      USD   3.99             21292                26
# 1        158578688      USD   0.00            161065                26
# 2        100524032      USD   0.00            188583              2822
# 3        128512000      USD   0.00            262241               649
# 4         92774400      USD   0.00            985920              5320
# ...            ...      ...    ...               ...               ...
# 7192     126644224      USD   0.00               142                75
# 7193     120760320      USD   0.00                30                30
# 7194     111322112      USD   1.99                15                 0
# 7195      97235968      USD   0.00                85                32
# 7196      90898432      USD   0.00                 3                 3
#
#       user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0             4.0              4.5   6.3.5          4+         Games
# 1             4.0              3.5   8.2.2          4+  Productivity
# 2             3.5              4.5   5.0.0          4+       Weather
# 3             4.0              4.5  5.10.0         12+      Shopping
# 4             4.5              5.0   7.5.1          4+     Reference
# ...           ...              ...     ...         ...           ...
# 7192          4.5              4.5     1.3          4+         Games
# 7193          4.5              4.5     0.9          4+         Games
# 7194          4.5              0.0   1.0.2          9+     Utilities
# 7195          4.5              4.5  1.0.15         12+         Games
# 7196          5.0              5.0     1.0          4+         Games
#
#       sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  \
# 0                  38                5        10        1
# 1                  37                5        23        1
# 2                  37                5         3        1
# 3                  37                5         9        1
# 4                  37                5        45        1
# ...               ...              ...       ...      ...
# 7192               38                5         1        1
# 7193               38                0         1        1
# 7194               37                1         1        1
# 7195               38                0         2        1
# 7196               40                0         2        1
#
#                                                app_desc         rating_group
# 0     SAVE 20%, now only $3.99 for a limited time!\n...  between 10k and 50k
# 1     Let Evernote change the way you organize your ...       more than 100k
# 2     Download the most popular free weather app pow...       more than 100k
# 3     The eBay app is the best way to find anything ...       more than 100k
# 4     On more than 250 million devices around the wo...       more than 100k
# ...                                                 ...                  ...
# 7192  Place the falling blocks correctly in order to...            below 10k
# 7193  A thrilling virtual reality roller coaster exp...            below 10k
# 7194  Rock star Bret Michaels, winner of Celebrity A...            below 10k
# 7195  VR Roller Coaster World is an app for Google C...            below 10k
# 7196  5 previous escape games plus 1 new game in one...            below 10k
#
# [7197 rows x 18 columns]

# %%
data.groupby('rating_group').user_rating.describe()
# Out:
#                        count      mean       std  min  25%  50%  75%  max
# rating_group
# below 10k             6181.0  3.401796  1.591411  0.0  3.0  4.0  4.5  5.0
# between 10k and 50k    666.0  4.307057  0.464462  2.0  4.0  4.5  4.5  5.0
# between 50k and 100k   132.0  4.227273  0.560683  2.0  4.0  4.5  4.5  5.0
# more than 100k         218.0  4.268349  0.517222  2.0  4.0  4.5  4.5  5.0

# %%
av_rating_per_group = data.groupby('rating_group').user_rating.mean()

# %%
av_rating_per_group
# Out:
# rating_group
# below 10k               3.401796
# between 10k and 50k     4.307057
# between 50k and 100k    4.227273
# more than 100k          4.268349
# Name: user_rating, dtype: float64

# %%
plt.plot(av_rating_per_group)

# %% [markdown]
# conclusion: Rating is the highest for the group between 10k and 50k reviews. The lowest for apps below 10k reviews.

# %% [markdown]
# # QUESTION 3
# Number of apps for which current version rating is higher, the same or lower than for the previous versions

# %%
def rating_current_vs_all(current_rating, all_rating):
    if current_rating < all_rating:
        return 'lower'
    elif current_rating == all_rating:
        return 'the same'
    else:
        return 'higher'
    

  
data['rating_current_vs_all'] = data.apply(lambda x: rating_current_vs_all(x['user_rating_ver'], x['user_rating']),axis=1)
data
# Out:
#               id                                       track_name_x  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# ...          ...                                                ...
# 7192  1187617475                                              Kubik
# 7193  1187682390                                  VR Roller-Coaster
# 7194  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 7195  1187838770          VR Roller Coaster World - Virtual Reality
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes_x currency  price  rating_count_tot  rating_count_ver  \
# 0        100788224      USD   3.99             21292                26
# 1        158578688      USD   0.00            161065                26
# 2        100524032      USD   0.00            188583              2822
# 3        128512000      USD   0.00            262241               649
# 4         92774400      USD   0.00            985920              5320
# ...            ...      ...    ...               ...               ...
# 7192     126644224      USD   0.00               142                75
# 7193     120760320      USD   0.00                30                30
# 7194     111322112      USD   1.99                15                 0
# 7195      97235968      USD   0.00                85                32
# 7196      90898432      USD   0.00                 3                 3
#
#       user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0             4.0              4.5   6.3.5          4+         Games
# 1             4.0              3.5   8.2.2          4+  Productivity
# 2             3.5              4.5   5.0.0          4+       Weather
# 3             4.0              4.5  5.10.0         12+      Shopping
# 4             4.5              5.0   7.5.1          4+     Reference
# ...           ...              ...     ...         ...           ...
# 7192          4.5              4.5     1.3          4+         Games
# 7193          4.5              4.5     0.9          4+         Games
# 7194          4.5              0.0   1.0.2          9+     Utilities
# 7195          4.5              4.5  1.0.15         12+         Games
# 7196          5.0              5.0     1.0          4+         Games
#
#       sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic  \
# 0                  38                5        10        1
# 1                  37                5        23        1
# 2                  37                5         3        1
# 3                  37                5         9        1
# 4                  37                5        45        1
# ...               ...              ...       ...      ...
# 7192               38                5         1        1
# 7193               38                0         1        1
# 7194               37                1         1        1
# 7195               38                0         2        1
# 7196               40                0         2        1
#
#                                                app_desc         rating_group  \
# 0     SAVE 20%, now only $3.99 for a limited time!\n...  between 10k and 50k
# 1     Let Evernote change the way you organize your ...       more than 100k
# 2     Download the most popular free weather app pow...       more than 100k
# 3     The eBay app is the best way to find anything ...       more than 100k
# 4     On more than 250 million devices around the wo...       more than 100k
# ...                                                 ...                  ...
# 7192  Place the falling blocks correctly in order to...            below 10k
# 7193  A thrilling virtual reality roller coaster exp...            below 10k
# 7194  Rock star Bret Michaels, winner of Celebrity A...            below 10k
# 7195  VR Roller Coaster World is an app for Google C...            below 10k
# 7196  5 previous escape games plus 1 new game in one...            below 10k
#
#      rating_current_vs_all
# 0                   higher
# 1                    lower
# 2                   higher
# 3                   higher
# 4                   higher
# ...                    ...
# 7192              the same
# 7193              the same
# 7194                 lower
# 7195              the same
# 7196              the same
#
# [7197 rows x 19 columns]

# %%
#data presented with bar chart
comparison_ratings = data.groupby('rating_current_vs_all')['id'].count()
bar_chart = comparison_ratings.plot.bar()
bar_chart.set_title('Current version rating compared with previous versions')
bar_chart.set_xlabel('rating')
bar_chart.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
#the same data presented using pie chart
pie_chart = comparison_ratings.plot.pie(autopct='%1.1f%%')

# %% [markdown]
# conclusion: For majority of the apps, rating of the current version is the same as for the previous versions. A bit more apps get lower rating per current version than higher.
